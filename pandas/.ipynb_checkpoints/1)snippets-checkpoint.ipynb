# %%
people={
    "first":["Abhishek","Ram","Shyam","Mohit"],
    "last":["Karn","Magar","Shah","Awasthi"],
    "email":["abhishek@gmail.com","rammagar@gmail.com","shyamah@yahoo.com","hitashi@gmail.com"]
}

# %%
people['email']
# Out:
# ['abhishek@gmail.com',
#  'rammagar@gmail.com',
#  'shyamah@yahoo.com',
#  'hitashi@gmail.com']

# %%
import pandas as pd

# %%
#Creating a dataframe
df=pd.DataFrame(people)

# %%
df
# Out:
#       first     last               email
# 0  Abhishek     Karn  abhishek@gmail.com
# 1       Ram    Magar  rammagar@gmail.com
# 2     Shyam     Shah   shyamah@yahoo.com
# 3     Mohit  Awasthi   hitashi@gmail.com

# %%
#Series:
#Returns a series: usually called 4D
df['email']
# Out:
# 0    abhishek@gmail.com
# 1    rammagar@gmail.com
# 2     shyamah@yahoo.com
# 3     hitashi@gmail.com
# Name: email, dtype: str

# %%
type(df['email'])
# Out:
# pandas.Series

# %%
df.email
# Out:
# 0    abhishek@gmail.com
# 1    rammagar@gmail.com
# 2     shyamah@yahoo.com
# 3     hitashi@gmail.com
# Name: email, dtype: str

# %%
type(df.email)
# Out:
# pandas.Series

# %%
df[['last','email']]
# Out:
#       last               email
# 0     Karn  abhishek@gmail.com
# 1    Magar  rammagar@gmail.com
# 2     Shah   shyamah@yahoo.com
# 3  Awasthi   hitashi@gmail.com

# %%
#It returns a series that contains the values of first row of data using index 0
df.iloc[0]
# Out:
# first              Abhishek
# last                   Karn
# email    abhishek@gmail.com
# Name: 0, dtype: str

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[[0,1],0]
# Out:
# 0    Abhishek
# 1         Ram
# Name: first, dtype: str

# %%
df.iloc[[0,1],[1,2]]
# Out:
#     last               email
# 0   Karn  abhishek@gmail.com
# 1  Magar  rammagar@gmail.com

# %%
#loc always the use of labels while iloc only allows indexes
df.loc[0]
# Out:
# first              Abhishek
# last                   Karn
# email    abhishek@gmail.com
# Name: 0, dtype: str

# %%
df.loc[[0,1],['last','email']]
# Out:
#     last               email
# 0   Karn  abhishek@gmail.com
# 1  Magar  rammagar@gmail.com

# %%
#BEGENNING OF : Indexing

# %%
df.set_index('email')
# Out:
#                        first     last
# email
# abhishek@gmail.com  Abhishek     Karn
# rammagar@gmail.com       Ram    Magar
# shyamah@yahoo.com      Shyam     Shah
# hitashi@gmail.com      Mohit  Awasthi

# %%
df
# Out:
#       first     last               email
# 0  Abhishek     Karn  abhishek@gmail.com
# 1       Ram    Magar  rammagar@gmail.com
# 2     Shyam     Shah   shyamah@yahoo.com
# 3     Mohit  Awasthi   hitashi@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                        first     last
# email
# abhishek@gmail.com  Abhishek     Karn
# rammagar@gmail.com       Ram    Magar
# shyamah@yahoo.com      Shyam     Shah
# hitashi@gmail.com      Mohit  Awasthi

# %%
df.index
# Out:
# Index(['abhishek@gmail.com', 'rammagar@gmail.com', 'shyamah@yahoo.com',
#        'hitashi@gmail.com'],
#       dtype='str', name='email')

# %%
df.loc['abhishek@gmail.com','first']
# Out:
# 'Abhishek'

# %%
df.iloc[0,1]
# Out:
# 'Karn'

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                 email     first     last
# 0  abhishek@gmail.com  Abhishek     Karn
# 1  rammagar@gmail.com       Ram    Magar
# 2   shyamah@yahoo.com     Shyam     Shah
# 3   hitashi@gmail.com     Mohit  Awasthi
